# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# !ls NBA
# Out:
# Nba_Engagments_ Dataset.csv

# %%
#import data table
df = pd.read_csv("NBA/Nba_Engagments_Dataset.csv",header=0,encoding = 'unicode_escape')
df.head(13)
# Out:
#     Engagements  Followers_at_Posting                  Created   Type  \
# 0        502093              36984682  2019-05-21 23:30:51 EDT  Video
# 1        603380              36984682  2019-05-21 22:53:33 EDT  Video
# 2        603380              36984682  2019-05-21 22:19:58 EDT  Video
# 3        725100              36984682  2019-05-21 22:02:41 EDT  Video
# 4        661446              36984682  2019-05-21 20:47:49 EDT  Video
# 5        322444              36955156  2019-05-21 14:02:32 EDT  Photo
# 6        722540              36955156  2019-05-21 12:30:53 EDT  Video
# 7        339265              36955156  2019-05-21 08:59:02 EDT  Photo
# 8        443330              36955156  2019-05-21 00:48:16 EDT  Photo
# 9        652193              36955156  2019-05-21 00:38:18 EDT  Video
# 10       652193              36955156  2019-05-21 00:31:13 EDT  Video
# 11       443330              36955156  2019-05-21 00:24:13 EDT  Photo
# 12       713427              36955156  2019-05-21 00:21:06 EDT  Video
#
#                                           Description
# 0   The @raptors bench trio of @sergeibaka @norman...
# 1   @kyle_lowry7 pulls from deep for the @raptors ...
# 2      @k_mid22 with some english on the @bucks dime!
# 3         Kawhi punches it home with the left on TNT!
# 4   @giannis_an34 goes baseline early to rock the ...
# 5   Congrats to the 2018-19 NBA All-Rookie First T...
# 6   The @warriors locked in for four games to adva...
# 7   Will the @bucks take a commanding 3-1 lead... ...
# 8   TAP to SHOP the @warriors Western Conference C...
# 9   Hey @stephencurry30... that was the first time...
# 10  @stephencurry30 (37/13/11) & @money23green (18...
# 11  The @warriors defeat @trailblazers 119-117 to ...
# 12  @money23green (18/14/11) reacts to a 5th strai...

# %%
#check if all the data was imported correctly 
#data includes training_set and holdout
df.shape
# Out:
# (8766, 5)

# %%
df.describe()*1000
# Out:
#         Engagements  Followers_at_Posting
# count  8.766000e+06          8.766000e+06
# mean   5.247436e+08          3.042875e+10
# std    2.528462e+08          3.752002e+09
# min    0.000000e+00          2.487554e+10
# 25%    3.535110e+08          2.697671e+10
# 50%    6.148005e+08          3.002376e+10
# 75%    7.097298e+08          3.392854e+10
# max    1.129585e+09          3.698468e+10

# %%
# check if there is any NaN values
df.isna().sum()
# Out:
# Engagements              0
# Followers_at_Posting     0
# Created                  0
# Type                     0
# Description             14
# dtype: int64

# %%
#split Created column to three columns (Date, time, TimeZone)
df[['Date','Time','TimeZone']] = df['Created'].str.split(' ',expand=True)
df
# Out:
#       Engagements  Followers_at_Posting                  Created   Type  \
# 0          502093              36984682  2019-05-21 23:30:51 EDT  Video
# 1          603380              36984682  2019-05-21 22:53:33 EDT  Video
# 2          603380              36984682  2019-05-21 22:19:58 EDT  Video
# 3          725100              36984682  2019-05-21 22:02:41 EDT  Video
# 4          661446              36984682  2019-05-21 20:47:49 EDT  Video
# 5          322444              36955156  2019-05-21 14:02:32 EDT  Photo
# 6          722540              36955156  2019-05-21 12:30:53 EDT  Video
# 8741  The best action from last night around the Ass...  2017-10-20  08:18:39
# 8742                                               ????  2017-10-19  22:12:34
# 8743  The reigning #KiaMVP @russwest44 warms up for ...  2017-10-19  17:17:39
# 8744  @joelembiid goes through his pregame warmup fo...  2017-10-18  18:15:01
# 8745                            ?????? #ThisIsWhyWePlay  2017-10-18  00:38:28
# 8746  Your team and fans are behind you, Gordon. Wis...  2017-10-17  23:22:04
# 8747                                #ThisIsWhyWePlay ??  2017-10-17  23:18:11
# 8748             The TOP 5 BLOCKS of the #NBAPreseason!  2017-10-15  12:59:04
# 8749  5 days from #KiaTipOff17... 5 days from the ne...  2017-10-12  18:59:50
# 8750                                             ??????  2017-10-12  15:30:24
# 8751               TBT to their @jrnba days! #JrNBAWeek  2017-10-12  11:47:21
# 8752                     ?? @kuzmakyle ?? #NBAPreseason  2017-10-11  00:22:47
# 8753                                    ?????? x ??????  2017-10-10  21:59:03
# 8754  9 days from #KiaTipOff17.... 9 days from more ...  2017-10-08  19:24:38
# 8755  10 days from #KiaTipOff17... 10 days from more...  2017-10-07  17:52:34
# 8756  New @cavs... @dwyanewade (20p), @bossmann99 (1...  2017-10-07  09:06:31
# 8757  The @warriors take their #NBAChinaGames portra...  2017-10-07  00:52:27
# 8758  @bensimmons dishes 9 assists in his first 22 m...  2017-10-04  23:31:03
# 8759  Join us in wishing Derrick Rose of the @cavs a...  2017-10-04  08:22:40
# 8760  @carmeloanthony puts up 19 in the first half o...  2017-10-03  23:26:45
# 8761             @kporzee with ???? swat! #NBAPreseason  2017-10-03  21:30:40
# 8762                           KD x KAT\n#NBAChinaGames  2017-10-03  07:25:54
# 8763  Jarrell Martin takes it to the rack STRONG for...  2017-10-02  20:55:59
# 8764  Ahead of tonights @celtics #NBAPreseason acti...  2017-10-02  17:36:15
# 8765  @DeAndre Jordan... the jam and the foul! #NBAP...  2017-10-01  23:53:18
#
#      TimeZone
# 0         EDT
# 1         EDT
# 2         EDT
# 3         EDT
# 4         EDT
# 5         EDT
# 6         EDT
# 7         EDT
# 8         EDT
# 9         EDT
# 10        EDT
# 11        EDT
# 12        EDT
# 13        EDT
# 14        EDT
# 15        EDT
# 16        EDT
# 17        EDT
# 18        EDT
# 19        EDT
# 20        EDT
# 21        EDT
# 22        EDT
# 23        EDT
# 24        EDT
# 25        EDT
# 26        EDT
# 27        EDT
# 28        EDT
# 29        EDT
# ...       ...
# 8736      EDT
# 8737      EDT
# 8738      EDT
# 8739      EDT
# 8740      EDT
# 8741      EDT
# 8742      EDT
# 8743      EDT
# 8744      EDT
# 8745      EDT
# 8746      EDT
# 8747      EDT
# 8748      EDT
# 8749      EDT
# 8750      EDT
# 8751      EDT
# 8752      EDT
# 8753      EDT
# 8754      EDT
# 8755      EDT
# 8756      EDT
# 8757      EDT
# 8758      EDT
# 8759      EDT
# 8760      EDT
# 8761      EDT
# 8762      EDT
# 8763      EDT
# 8764      EDT
# 8765      EDT
#
# [8766 rows x 8 columns]

# %%
#create columns for year, month, day, weekday
df['Year'] = pd.DatetimeIndex(df['Created']).year
# Index(['#', 'Player', 'Team_x', 'TS%', 'eFG%', 'Total S %', 'ORB%', 'DRB%',
#        'TRB%', 'AST%', 'TOV%', 'STL%', 'BLK%', 'USG%', 'PPR', 'PPS', 'ORtg',
#        'DRtg', 'eDiff', 'FIC', 'PER', 'year', 'position', 'colyear', 'Pick',
#        'drafted'],
#       dtype='object')

# %%
#change columns with numeric data to numeric
cols = ['position', 'colyear']
df_final[cols] = df_final[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
#check column types
df_final.dtypes
# Out:
# #             object
# Player        object
# Team_x        object
# TS%          float64
# eFG%         float64
# Total S %    float64
# ORB%         float64
# DRB%         float64
# TRB%         float64
# AST%         float64
# TOV%         float64
# STL%         float64
# BLK%         float64
# USG%         float64
# PPR          float64
# PPS          float64
# ORtg         float64
# DRtg         float64
# eDiff        float64
# FIC          float64
# PER          float64
# year         float64
# position       int64
# colyear        int64
# Pick         float64
# drafted        int64
# dtype: object

# %%
#drop any Na columns
df_final.dropna
# Out:
# <bound method DataFrame.dropna of          #              Player   Team_x    TS%   eFG%  Total S %  ORB%  DRB%  \
# 0        1          Seth Curry      LIB  0.544  0.505      159.7   2.3  11.2
# 1        2         Matt Dickey     UNCA  0.612  0.569      168.3   4.3  11.9
# 2        3       Isaiah Thomas       UW  0.511  0.463      139.3   2.8   8.7
# 3        4          Paul McCoy      SMU  0.528  0.506      147.2   3.7   9.9
# 4        5       Erving Walker       UF  0.598  0.566      163.8   0.8   6.3
# 5        6        Kemba Walker    UConn  0.549  0.498      145.6   3.9  10.2
# 6        7          R.J. Evans       HC  0.482  0.465      123.3   8.8  13.1
# 7        8    Courtney Fortson   U of A  0.495  0.467      133.7   5.6  12.8
# 8        9     Ben Drayton III      GSU  0.591  0.559      168.7   2.5   7.6
# 9       10          Doug Davis     PRIN  0.552  0.535      156.8   1.5   6.9
# 10      11       Daniel Bryant      ASU  0.485  0.465      133.9   2.4  11.1
# 11      12    Frankie Sullivan       AU  0.540  0.505      149.1   2.0   9.2
# 12      13       Kevin Dillard      SIU  0.568  0.540      162.1   0.9   7.4
# 13      14    Kwamain Mitchell      SLU  0.538  0.504      145.7   2.2  10.6
# 14      15       Jamar Briscoe     NCCU  0.514  0.459      151.4   1.9   6.9
# 15      16       Scott Machado       IC  0.504  0.439      137.7   3.6  11.7
# 16      17       Anthony Miles       LU  0.470  0.442      123.6   4.8  14.4
# 17      18            Dee Bost      MSU  0.503  0.436      139.9   2.7   9.0
# 18      19           C.J. Reed      BCU  0.456  0.407      135.2   1.5   9.0
# 19      20     Michael Griffin    PVAMU  0.502  0.481      142.8   3.4   7.7
# 20      21    De'Marion Gordon     USCU  0.530  0.473      153.4   3.5   8.6
# 21      22          J.P. Primm     UNCA  0.518  0.470      148.8   2.4   8.6
# 22      23  Brandon Richardson      UNL  0.568  0.500      153.4   1.5   9.3
# 23      24          Jio Fontan     FORD  0.458  0.422      131.4   1.9   7.4
# 24      25       Will Campbell       MU  0.546  0.491      161.0   2.8   8.9
# 25      26         Devon Moore      JMU  0.603  0.533      164.5   3.9   9.3
# 26216         5        4   0.0        0
# 26217         5        4   0.0        0
# 26218         5        4   0.0        0
# 26219         5        4   0.0        0
# 26220         5        4   0.0        0
# 26221         5        4   0.0        0
# 26222         5        4   0.0        0
# 26223         5        4   0.0        0
# 26224         5        4   0.0        0
# 26225         5        4   0.0        0
# 26226         5        4   0.0        0
# 26227         5        4   0.0        0
# 26228         5        4   0.0        0
# 26229         5        4   0.0        0
#
# [25399 rows x 26 columns]>

# %%
df_final.isna().sum()
# Out:
# #            0
# Player       0
# Team_x       0
# TS%          2
# eFG%         0
# Total S %    0
# ORB%         0
# DRB%         0
# TRB%         0
# AST%         0
# TOV%         0
# STL%         0
# BLK%         0
# USG%         0
# PPR          0
# PPS          0
# ORtg         0
# DRtg         0
# eDiff        0
# FIC          0
# PER          0
# year         0
# position     0
# colyear      0
# Pick         0
# drafted      0
# dtype: int64

# %%
#check to see if any columns still have zero values 
(df_final == 0).sum()
# Out:
# #                0
# Player           0
# Team_x           0
# TS%              0
# eFG%             0
# Total S %        0
# ORB%            12
# DRB%             1
# TRB%             1
# AST%             3
# TOV%             0
# STL%             9
# BLK%          1660
# USG%             0
# PPR            268
# PPS              0
# ORtg             0
# DRtg             0
# eDiff           69
# FIC              0
# PER              1
# year             0
# position         0
# colyear          0
# Pick         24948
# drafted      24948
# dtype: int64

# %%
#col = ['ORB%','DRB%','TRB%','AST%','STL%','BLK%','PPR','eDiff','PER',
       #'3PM','3PA','3P%','FTM','FTA','FT%','ORB','DRB','REB','AST','BLK']
#for i in col:
    #min_value = df_final[i].min(skipna=True)
    #df_final[i] = df_final[i].replace(0,min_value)

# %%
#(df_final == 0).sum()

# %% [markdown]
# ## Feature Selection

# %%
#check the coefficient of variation of each column 
coefficient_of_variation = (df_final.std()/df_final.mean())*100
coefficient_of_variation.sort_values(ascending=[False])
# Out:
# Pick         867.024840
# drafted      743.769125
# eDiff        423.864329
# BLK%         119.681844
# ORB%          73.530561
# AST%          56.940487
# STL%          51.402237
# FIC           49.993602
# position      49.419863
# TRB%          42.853717
# colyear       39.314159
# PER           37.087554
# DRB%          36.901049
# TOV%          31.304722
# USG%          24.434000
# Total S %     14.408387
# PPS           13.775038
# eFG%          12.708963
# TS%           10.775897
# ORtg          10.656644
# DRtg           6.036678
# year           0.157491
# PPR         -130.063805
# #                   NaN
# dtype: float64

# %%
#drop features with +100% coefficient_of_variation and very low %
df_final = df_final.drop(['BLK%','eDiff','PPR','DRtg','ORtg','TS%','PPS','Total S %','USG%'], axis = 1)

# %%
#split the data into train and test split
df_final_train = df_final[df_final['year'].isin([2009,2010,2011,2012,2013,2015,2016,2017])]
df_final_test = df_final[df_final['year'].isin([2018])]

# %%
#check the shape of the data
df_final_train.shape
# Out:
# (18367, 17)

# %%
df_final.columns
# Out:
# Index(['#', 'Player', 'Team_x', 'eFG%', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'TOV%',
#        'STL%', 'FIC', 'PER', 'year', 'position', 'colyear', 'Pick', 'drafted'],
#       dtype='object')

# %%
df_final = df_final.fillna(0)

# %%
# Split into features and target / train-test split
X_train = df_final_train.iloc[:,3:-2]
y_train = df_final_train.iloc[:, -1]

X_test = df_final_test.iloc[:,3:-2]
y_test = df_final_test.iloc[:, -1]

# %%
#check the shape of 
print(X_train.shape)
print(y_train.shape)
# Out:
# (18367, 12)
# (18367,)

# %%
#show the final list of columns with teh coefficient_of_variation
coefficient_of_variation2 = (X_train.std()/X_train.mean())*100
coefficient_of_variation2.sort_values(ascending=[False])
# Out:
# ORB%        70.901817
# AST%        56.945565
# STL%        53.575141
# FIC         50.316097
# position    49.427257
# TRB%        42.921539
# colyear     39.213050
# DRB%        36.942719
# PER         35.749789
# TOV%        31.410357
# eFG%        12.696530
# year         0.135181
# dtype: float64

# %%
#show the above in a cleaner dataframe
results_frame = pd.DataFrame({'feature': X_train.columns,
                             'coefficient_of_variation': coefficient_of_variation2
                             })

results_frame_sorted = results_frame.sort_values(by='coefficient_of_variation',ascending=[False])
results_frame_sorted
# Out:
#            feature  coefficient_of_variation
# ORB%          ORB%                 70.901817
# AST%          AST%                 56.945565
# STL%          STL%                 53.575141
# FIC            FIC                 50.316097
# position  position                 49.427257
# TRB%          TRB%                 42.921539
# colyear    colyear                 39.213050
# DRB%          DRB%                 36.942719
# PER            PER                 35.749789
# TOV%          TOV%                 31.410357
# eFG%          eFG%                 12.696530
# year          year                  0.135181

# %%
#check for the mutual info score of each feature

from sklearn.metrics import adjusted_mutual_info_score

mutual_info_scores = []

for feature in X_train.columns:
    #calcualte the mutual info score
    m_info = adjusted_mutual_info_score(X_train[feature], y_train)
    #append it to our list
    mutual_info_scores.append(m_info)

# %%
#put the mutual info score in a dataframe
results_frame = pd.DataFrame({'feature': X_train.columns,
                             'mutual_info_scores': mutual_info_scores
                             })

results_frame_sorted = results_frame.sort_values(by='mutual_info_scores',ascending=[False])
results_frame_sorted
# Out:
#      feature  mutual_info_scores
# 8        PER            0.005093
# 7        FIC            0.003854
# 3       TRB%            0.001278
# 2       DRB%            0.001268
# 10  position            0.000877
# 0       eFG%            0.000776
# 1       ORB%            0.000560
# 11   colyear            0.000407
# 4       AST%            0.000390
# 5       TOV%            0.000220
# 6       STL%            0.000041
# 9       year           -0.000071

# %%
#plot the results
plt.figure(figsize=(15,10))
plt.bar(X_train.columns, mutual_info_scores)
plt.ylabel('Mutual info shared with Target')
plt.xticks(rotation=90)
plt.plot()
# Out:
# []

# %%
# check the 0 & 1 counts
y_train.value_counts()
# Out:
# 0    18004
# 1      363
# Name: drafted, dtype: int64

# %%
# craate a better balance between the two classes by applying smote with (20% of data being class 1)
#from imblearn.over_sampling import SMOTE

#Instantiate
#smote = SMOTE(ratio=.25)

#fit & resample
#X_train_res, y_train_res = smote.fit_sample(X_train, y_train)

# we fit the model on X_train_res, y_train_res

# %%
#np.unique(y_train_res, return_counts=True)

#now we have an evenly balanced training set to fit our model

# %% [markdown]
# # Build the model, check score, and results

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
#scale the data
scaler = StandardScaler()
scaler.fit(X_train)
#transform the data
#X_train = scaler.transform(X_train)
#X_test = scaler.transform(X_test)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
#scale the X_train res and X_test data
X_train = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score, precision_score
# Instantiate and fit
logistic_regression_model = LogisticRegression(solver = 'lbfgs')
logistic_regression_model.fit(X_train, y_train)

# predict
y_pred_train = logistic_regression_model.predict(X_train)
y_pred_test = logistic_regression_model.predict(X_test)

# Evaluate it
train_f1_score  = f1_score(y_train,y_pred_train)
test_f1_score = f1_score(y_test,y_pred_test)
test_recall_score = recall_score(y_test,y_pred_test)
print(f"The classification train f1_score is: {train_f1_score:0.3f}")
print(f"The classification test f1_socre is: {test_f1_score:0.3f}")
print(f"The classification test recall_score is: {test_recall_score:0.3f}")
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred_test))
# Out:
# The classification train f1_score is: 0.304
# The classification test f1_socre is: 0.281
# The classification test recall_score is: 0.178
# Confusion Matrix:
#  [[2266    4]
#  [  37    8]]

# %%
#check the coefficient of each feature
results_frame = pd.DataFrame({'feature': X_train.columns,
                             'coefficient': logistic_regression_model.coef_[0]
                             })

results_frame_sorted = results_frame.sort_values(by='coefficient')
results_frame_sorted
# Out:
#      feature  coefficient
# 2       DRB%    -1.503213
# 1       ORB%    -1.241131
# 4       AST%    -0.542824
# 11   colyear    -0.520370
# 0       eFG%    -0.371226
# 6       STL%    -0.214419
# 9       year    -0.081473
# 10  position     0.215093
# 5       TOV%     0.477013
# 8        PER     0.702262
# 3       TRB%     1.518596
# 7        FIC     2.039366

# %%
#Check the AUC curve
y_test_proba = logistic_regression_model.predict_proba(X_test)[:,1]

from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, y_test_proba)
roc_auc = auc(fpr, tpr)

print(roc_auc)

plt.figure()
plt.plot(fpr, tpr, color='orange')
plt.plot([0,1], [0,1], color='black', linestyle='--')
plt.show()
# Out:
# 0.9309838472834068

# %%
#get the threshold where recall score = 70%
thresholds[tpr> 0.7]*100
# Out:
# array([6.63004800e+00, 6.59761272e+00, 6.58076148e+00, 6.08579802e+00,
#        6.04481864e+00, 5.98547962e+00, 5.96340167e+00, 5.72333614e+00,
#        5.69278538e+00, 5.29325257e+00, 5.26081278e+00, 4.24247197e+00,
#        4.20369169e+00, 4.00755234e+00, 3.97551020e+00, 2.17518610e+00,
#        2.16526672e+00, 1.55613766e+00, 1.55582725e+00, 1.05580576e+00,
#        1.05556906e+00, 6.65351259e-01, 6.64542474e-01, 5.27839400e-01,
#        5.23522494e-01, 8.21481199e-02, 8.20558688e-02, 4.27769484e-07])

# %%
y_pred_proba = (logistic_regression_model.predict_proba(X_test,)[:,1]>0.0663).astype(bool)

print('Recall:', recall_score(y_test, y_pred_proba))
print('Precision:', precision_score(y_test, y_pred_proba))
print('f1:', f1_score(y_test, y_pred_proba))
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred_proba))
# Out:
# Recall: 0.7111111111111111
# Precision: 0.2
# f1: 0.31219512195121946
# Confusion Matrix:
#  [[2142  128]
#  [  13   32]]

# %%
#count of all  draft values == 1
y_pred_proba.sum()
# Out:
# 160

# %%
# show results of y predictions and the probability of each player getting drafted
y_pred_proba_drafted = df_final_test[y_pred_proba ==1]
y_pred_proba_drafted['y_pred_prob'] = logistic_regression_model.predict_proba(X_test)[:,1][y_pred_proba ==1]

# %%
y_pred_proba_drafted
# Out:
# 23468  12.2   1.0  406.9  22.4  2018.0         5        4   0.0        0
# 23471  15.6   1.3  418.8  21.0  2018.0         5        4   0.0        0
# 23495   9.3   1.3  378.4  18.8  2018.0         5        4   0.0        0
#
#        y_pred_prob
# 21380     0.856201
# 21382     0.084971
# 21383     0.252956
# 21385     0.150455
# 21480     0.157271
# 21481     0.132154
# 21482     0.226788
# 21483     0.470720
# 21583     0.073345
# 21591     0.097599
# 21596     0.121224
# 21662     0.954998
# 21663     0.675853
# 21664     0.075497
# 21666     0.251659
# 21673     0.231322
# 21680     0.095123
# 21682     0.217111
# 21730     0.906152
# 21731     0.357283
# 21732     0.251467
# 21733     0.080186
# 21736     0.418338
# 21737     0.101089
# 21824     0.176868
# 21826     0.215353
# 21827     0.111864
# 21828     0.133133
# 21829     0.159701
# 21834     0.151237
# ...            ...
# 23068     0.227652
# 23071     0.067744
# 23156     0.083762
# 23159     0.143500
# 23161     0.084465
# 23164     0.107392
# 23176     0.124829
# 23256     0.098208
# 23258     0.305962
# 23270     0.147022
# 23287     0.189194
# 23293     0.076074
# 23354     0.081591
# 23355     0.226842
# 23357     0.129765
# 23359     0.288628
# 23360     0.077745
# 23361     0.386070
# 23363     0.351831
# 23364     0.091229
# 23365     0.337406
# 23369     0.142216
# 23381     0.134265
# 23382     0.086425
# 23387     0.219911
# 23454     0.745343
# 23459     0.078631
# 23468     0.074054
# 23471     0.071620
# 23495     0.073667
#
# [160 rows x 18 columns]

# %%
# show the pobablity of each player getting drafted 
drafted = y_pred_proba_drafted.sort_values(by=['y_pred_prob'], ascending=False)
drafted
# Out:
#         #                   Player    Team_x   eFG%  ORB%  DRB%  TRB%  AST%  \
# 21662   1            Deandre Ayton    U of A  0.625  13.5  28.2  21.4  10.2
# 21730   1        Marvin Bagley III      DUKE  0.640  13.7  21.4  17.8   8.5
# 22483   3               Jon Elmore        MU  0.526   1.2  14.1   8.0  32.5
# 21380   1               Trae Young        OU  0.518   1.3   9.9   5.8  48.6
# 22781   1                Mike Daum      SDSU  0.543   6.7  28.2  17.9   9.0
# 22581   1            Mikal Bridges      VILL  0.623   5.2  13.8   9.7  10.6
# 23454   1             Jock Landale       SMC  0.644  12.6  26.8  20.2  13.5
# 22683   3             Ajdin Penava        MU  0.610   7.6  22.1  15.3  12.5
# 21663   2       Wendell Carter Jr.      DUKE  0.591  12.8  23.1  18.3  12.9
# 23067  14          Devonte' Graham        KU  0.510   2.0   9.6   6.0  31.4
# 22383   3            Jalen Brunson      VILL  0.604   1.2   9.7   5.6  26.6
# 22682   2         Keita Bates-Diop       OSU  0.544   5.7  24.5  15.5  10.5
# 22127   4             Yoeli Childs       BYU  0.557   7.7  23.5  15.9  14.6
# 21483   4  Shai Gilgeous-Alexander        UK  0.516   3.2  10.0   6.8  28.8
# 22598  18              Cody Martin       UNR  0.537   5.9  13.6   9.9  23.8
# 22692  12                Luke Maye       UNC  0.535  10.3  22.8  16.7  13.8
# 21736   7            Brandon McCoy      UNLV  0.548  12.7  25.1  19.4   3.5
# [160 rows x 18 columns]

# %%
#shw the rank of each player
df_drafted = drafted[drafted['drafted'].isin([1])]
df_drafted
# Out:
#         #                   Player   Team_x   eFG%  ORB%  DRB%  TRB%  AST%  \
# 21662   1            Deandre Ayton   U of A  0.625  13.5  28.2  21.4  10.2
# 21730   1        Marvin Bagley III     DUKE  0.640  13.7  21.4  17.8   8.5
# 21380   1               Trae Young       OU  0.518   1.3   9.9   5.8  48.6
# 22581   1            Mikal Bridges     VILL  0.623   5.2  13.8   9.7  10.6
# 21663   2       Wendell Carter Jr.     DUKE  0.591  12.8  23.1  18.3  12.9
# 23067  14          Devonte' Graham       KU  0.510   2.0   9.6   6.0  31.4
# 22383   3            Jalen Brunson     VILL  0.604   1.2   9.7   5.6  26.6
# 22682   2         Keita Bates-Diop      OSU  0.544   5.7  24.5  15.5  10.5
# 21483   4  Shai Gilgeous-Alexander       UK  0.516   3.2  10.0   6.8  28.8
# 21731   2            Mohamed Bamba       UT  0.567  12.2  28.3  20.2   3.6
# 22027   4                Tony Carr      PSU  0.482   3.0  13.5   8.3  29.3
# 23056   3             Jevon Carter      WVU  0.498   2.4  13.2   7.5  36.2
# 22025   2            Miles Bridges      MSU  0.535   5.2  18.1  12.4  16.8
# 21732   3        Jaren Jackson Jr.      MSU  0.595   8.8  19.7  14.9   9.3
# 21673  12           Omari Spellman     VILL  0.573   9.9  23.0  16.8   4.3
# 22391  11            Aaron Holiday     UCLA  0.557   1.6   8.7   5.3  29.9
# 21931   8         Donte DiVincenzo     VILL  0.590   4.9  13.8   9.6  20.0
# 21480   1             Zhaire Smith      TTU  0.588   9.5  11.1  10.4  12.5
# 22600  20          Jerome Robinson       BC  0.564   1.5   9.8   5.6  19.5
# 23369  16             Kevin Hervey      UTA  0.517   8.0  20.1  14.3  15.2
# 22802  22            Chimezie Metu      USC  0.538   7.3  21.0  14.2  10.0
# 22688   8         Raymond Spalding   U of L  0.550  13.3  20.9  17.3   9.6
# 23176  23            Grayson Allen     DUKE  0.536   1.8   8.0   5.1  21.1
# 21596  17           Gary Trent Jr.     DUKE  0.528   2.9  10.3   6.8   6.8
# 21930   7            Landry Shamet      WSU  0.622   1.6   9.6   5.7  28.9
# 21591  12               Kevin Knox       UK  0.510   3.3  14.4   9.3   8.7
# 22148  25            Kevin Huerter      UMD  0.616   3.8  12.9   8.8  20.3
# 23382  29            Vince Edwards       PU  0.544   8.3  18.5  13.8  17.1
# 21382   3            Collin Sexton       UA  0.498   4.1   9.8   7.0  27.7
# 22791  11               Moe Wagner       UM  0.605   6.5  25.0  15.8   6.8
# 22490  10             Khyri Thomas       CU  0.629   4.0  11.0   7.7  15.1
# 22596  16       Melvin Frazier Jr.       TU  0.610   3.9  14.6   9.3  18.0
#
#        TOV%  STL%    FIC   PER    year  position  colyear  Pick  drafted  \
# 21662  11.3   1.0  660.9  30.6  2018.0         4        1   1.0        1
# 21730  12.2   1.4  594.1  28.3  2018.0         5        1   2.0        1
# 21380  18.2   2.5  552.5  26.9  2018.0         1        1   5.0        1
# 22581   9.1   2.7  556.0  25.4  2018.0         3        3  10.0        1
# 21663  15.8   1.7  529.8  26.4  2018.0         4        1   7.0        1
# 23067  15.5   2.4  558.5  20.2  2018.0         1        4  34.0        1
# 22383  10.7   1.7  513.2  24.7  2018.0         1        3  33.0        1
# 22682   9.6   1.6  520.4  26.3  2018.0         4        3  48.0        1
# 21483  17.9   2.8  443.6  20.1  2018.0         2        1  11.0        1
# 21731  12.3   1.5  465.9  26.5  2018.0         5        1   6.0        1
# 22027  11.0   1.4  459.5  21.3  2018.0         3        2  51.0        1
# 23056  14.4   5.0  553.9  23.7  2018.0         1        4  32.0        1
# 22025  11.6   1.2  432.4  21.7  2018.0         3        2  12.0        1
# 21732  17.4   1.6  370.4  25.1  2018.0         5        1   4.0        1
# 21673   9.8   1.3  448.0  19.6  2018.0         4        1  30.0        1
# 22391  18.5   1.9  422.5  20.0  2018.0         1        3  23.0        1
# 21931  15.2   2.0  426.1  20.0  2018.0         2        2  17.0        1
# 21480  10.8   2.3  396.6  21.5  2018.0         2        1  16.0        1
# 22600  13.9   1.4  384.5  20.2  2018.0         3        3  13.0        1
# 23369  12.8   2.1  459.5  22.7  2018.0         4        4  57.0        1
# 22802  12.8   1.5  415.2  22.2  2018.0         5        3  49.0        1
# 22688  13.5   3.1  458.2  24.1  2018.0         4        3  56.0        1
# 23176  13.8   2.7  416.4  17.8  2018.0         2        4  21.0        1
# 21596   7.4   1.9  335.9  16.0  2018.0         3        1  37.0        1
# 21930  15.5   1.3  380.4  20.2  2018.0         2        2  26.0        1
# 21591  14.1   1.5  310.8  16.5  2018.0         3        1   9.0        1
# 22148  17.8   1.1  352.9  18.4  2018.0         4        2  19.0        1
# 23382  14.0   1.0  432.5  20.7  2018.0         4        4  52.0        1
# 21382  14.2   1.6  328.0  22.4  2018.0         1        1   8.0        1
# 22791  10.8   2.2  420.5  23.8  2018.0         5        3  25.0        1
# 22490  13.4   2.9  391.4  20.6  2018.0         2        3  38.0        1
# 22596  16.9   3.5  390.0  21.0  2018.0         3        3  35.0        1
#
#        y_pred_prob
# 21662     0.954998
# 21730     0.906152
# 21380     0.856201
# 22581     0.771290
# 21663     0.675853
# 23067     0.629281
# 22383     0.565160
# 22682     0.552826
# 21483     0.470720
# 21731     0.357283
# 22027     0.354510
# 23056     0.336323
# 22025     0.267323
# 21732     0.251467
# 21673     0.231322
# 22391     0.192615
# 21931     0.177402
# 21480     0.157271
# 22600     0.156321
# 23369     0.142216
# 22802     0.135829
# 22688     0.132194
# 23176     0.124829
# 21596     0.121224
# 21930     0.099216
# 21591     0.097599
# 22148     0.086878
# 23382     0.086425
# 21382     0.084971
# 22791     0.082608
# 22490     0.080010
# 22596     0.066300

# %% [markdown]
# # Rebuild model with fewer features, Grid Search and different Classification Models

# %% [markdown]
# ### Drop Columns with low mutual_info_scores and refit

# %%
results_frame = pd.DataFrame({'feature': X_train.columns,
                            'mutual_info_scores': mutual_info_scores
                             })

results_frame_sorted = results_frame.sort_values(by='mutual_info_scores',ascending=[False])
results_frame_sorted
# Out:
#      feature  mutual_info_scores
# 8        PER            0.005093
# 7        FIC            0.003854
# 3       TRB%            0.001278
# 2       DRB%            0.001268
# 10  position            0.000877
# 0       eFG%            0.000776
# 1       ORB%            0.000560
# 11   colyear            0.000407
# 4       AST%            0.000390
# 5       TOV%            0.000220
# 6       STL%            0.000041
# 9       year           -0.000071

# %%
#Drop all columns with very low scores 
df_final = df_final.drop(['TOV%','STL%','AST%','TRB%'], axis = 1)

# %%
df_final.columns
# Out:
# Index(['#', 'Player', 'Team_x', 'eFG%', 'ORB%', 'DRB%', 'FIC', 'PER', 'year',
#        'position', 'colyear', 'Pick', 'drafted'],
#       dtype='object')

# %%
#split the data into train and test split
df_final_train = df_final[df_final['year'].isin([2009,2010,2011,2012,2013,2015,2016,2017])]
df_final_test = df_final[df_final['year'].isin([2018])]

# %%
#check the shape of the data
df_final_train.shape
# Out:
# (18367, 13)

# %%
# Split into features and target / train-test split
X_train = df_final_train.iloc[:,3:-2]
y_train = df_final_train.iloc[:, -1]

X_test = df_final_test.iloc[:,3:-2]
y_test = df_final_test.iloc[:, -1]

# %%
#check the shape of 
print(X_train.shape)
print(y_train.shape)
# Out:
# (18367, 8)
# (18367,)

# %%
#scale the data
scaler = StandardScaler()
scaler.fit(X_train)
#transform the data
#X_train = scaler.transform(X_train)
#X_test = scaler.transform(X_test)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA, KernelPCA

# Instantiate objects that we want in our pipeline 
scaler = StandardScaler()
logreg = LogisticRegression()

# Create a list of ('name', object)-tuples that will make up our pipeline
estimators = [('my_scaler', scaler), 
              (('PCA'), PCA()),
              ('my_model', logreg)]

# Instantiate the Pipeline itself
my_pipe = Pipeline(estimators)

# %%
my_params = [
{'my_scaler': [scaler], 
'PCA':[PCA()], 'PCA__n_components':np.arange(1, 9),
'my_model': [LogisticRegression()], 'my_model__C': np.power(10.0, np.arange(-5, 5, .5)),
'my_model__penalty': ['l1', 'l2']}]
#{'my_scaler': [scaler],
#'PCA':[PCA()], 'PCA__n_components':np.arange(1, 26),
#'my_model': [RandomForestClassifier()], 'my_model__n_estimators':[10, 50, 100, 200],
#'my_model__max_features': ['auto', None, 0.1, 0.25, 0.5, 0.75]}]

grid = GridSearchCV(my_pipe, param_grid = my_params, cv = 5, scoring='f1')

# %%
fitted_search = grid.fit(X_train, y_train)

# %%
fitted_search.best_estimator_
# Out:
# Pipeline(memory=None,
#      steps=[('my_scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('PCA', PCA(copy=True, iterated_power='auto', n_components=8, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)), ('my_model', LogisticRegression(C=3.1622776601683795, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='warn', n_jobs=None, penalty='l1', random_state=None,
#           solver='warn', tol=0.0001, verbose=0, warm_start=False))])

# %%
# Take a look at the winning estimator. Here's how we can access the coefficients of the 
# Logistic Regression object
model_coef = fitted_search.best_estimator_.named_steps['my_model'].coef_[0]
model_coef
# Out:
# array([ 0.62318826,  0.79013658,  0.102225  ,  0.72808223,  0.7163724 ,
#        -0.70248861, -1.2299011 , -0.61407745])

# %%
results_frame = pd.DataFrame({'feature': X_train.columns,
                             'coefficient': fitted_search.best_estimator_.named_steps['my_model'].coef_[0]
                             })

results_frame_sorted = results_frame.sort_values(by='coefficient',  ascending=False)
results_frame_sorted
# Out:
#     feature  coefficient
# 1      ORB%     0.790137
# 3       FIC     0.728082
# 4       PER     0.716372
# 0      eFG%     0.623188
# 2      DRB%     0.102225
# 7   colyear    -0.614077
# 5      year    -0.702489
# 6  position    -1.229901

# %% [markdown]
# **The model shows that the below 4 variables have the highest impact on player getting drafted or not.**
# - ORB% 0.790124 , FIC	0.728064, PER	0.716360, eFG%	0.623179
#
# **the below 3 variables shows a negative impact of the players selection process.**
# - colyear	-0.614080, position	-1.229878
#
# **Understanding each stat, players tend to be selected on offensive results vs defensive results. college year and position effect the player negatively as the more you stay in college the less you are likely to be selected. NBA teams tend to want to have the player to be as young as possible to be able to have a bigger impact on player development.**

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# Evaluate our best model
y_pred = fitted_search.best_estimator_.predict(X_test)

print('Recall:', recall_score(y_test, y_pred))
print('Precision:', precision_score(y_test, y_pred))
print('f1:', f1_score(y_test, y_pred))
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred))
# Out:
# Recall: 0.17777777777777778
# Precision: 0.5714285714285714
# f1: 0.2711864406779661
# Confusion Matrix:
#  [[2264    6]
#  [  37    8]]

# %%
mybestpipeline = fitted_search.best_estimator_

y_test_proba = mybestpipeline.predict_proba(X_test)[:,1]

from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, y_test_proba)
roc_auc = auc(fpr, tpr)

print(roc_auc)

plt.figure()
plt.plot(fpr, tpr, color='orange')
plt.plot([0,1], [0,1], color='black', linestyle='--')
plt.show()
# Out:
# 0.9278120411160059

# %%
thresholds[tpr> 0.7]*100
# Out:
# array([8.02919889e+00, 7.83242703e+00, 7.76683826e+00, 7.27015588e+00,
#        7.20015050e+00, 7.16566257e+00, 7.12716262e+00, 5.60146469e+00,
#        5.56843546e+00, 5.07104789e+00, 5.03828561e+00, 4.94922442e+00,
#        4.93072410e+00, 4.58824470e+00, 4.56542724e+00, 2.44768453e+00,
#        2.44209360e+00, 1.73862348e+00, 1.73671404e+00, 1.08471018e+00,
#        1.07581800e+00, 4.31799705e-01, 4.31348249e-01, 3.88315293e-01,
#        3.85878108e-01, 5.82120392e-02, 5.82027861e-02, 3.19040317e-03])

# %%
y_pred_proba = (fitted_search.best_estimator_.predict_proba(X_test,)[:,1]>0.08).astype(bool)

print('Recall:', recall_score(y_test, y_pred_proba))
print('Precision:', precision_score(y_test, y_pred_proba))
print('f1:', f1_score(y_test, y_pred_proba))
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred_proba))
# Out:
# Recall: 0.7111111111111111
# Precision: 0.22695035460992907
# f1: 0.34408602150537637
# Confusion Matrix:
#  [[2161  109]
#  [  13   32]]

# %%
X_train.columns
# Out:
# Index(['eFG%', 'ORB%', 'DRB%', 'FIC', 'PER', 'year', 'position', 'colyear'], dtype='object')

# %%
y_pred_proba.sum()
# Out:
# 141

# %%
y_pred_proba_drafted = df_final_test[y_pred_proba ==1]
y_pred_proba_drafted['y_pred_prob'] = fitted_search.best_estimator_.predict_proba(X_test,)[:,1][y_pred_proba ==1]

# %%
y_pred_proba_drafted
# Out:
#         #                   Player   Team_x   eFG%  ORB%  DRB%    FIC   PER  \
#
# 21867  2018.0         1        2   0.0        0     0.093815
# 21924  2018.0         2        2   0.0        0     0.253674
# ...       ...       ...      ...   ...      ...          ...
# 23060  2018.0         1        4   0.0        0     0.086685
# 23061  2018.0         1        4   0.0        0     0.082260
# 23067  2018.0         1        4  34.0        1     0.574660
# 23068  2018.0         1        4   0.0        0     0.313884
# 23156  2018.0         2        4   0.0        0     0.093586
# 23159  2018.0         2        4   0.0        0     0.141190
# 23161  2018.0         2        4   0.0        0     0.083404
# 23164  2018.0         2        4   0.0        0     0.090080
# 23176  2018.0         2        4  21.0        1     0.114502
# 23256  2018.0         3        4   0.0        0     0.126040
# 23258  2018.0         3        4   0.0        0     0.265120
# 23270  2018.0         3        4   0.0        0     0.098540
# 23276  2018.0         3        4   0.0        0     0.083415
# 23283  2018.0         3        4   0.0        0     0.093355
# 23287  2018.0         3        4   0.0        0     0.230971
# 23354  2018.0         4        4   0.0        0     0.081333
# 23355  2018.0         4        4   0.0        0     0.326364
# 23357  2018.0         4        4   0.0        0     0.089325
# 23359  2018.0         4        4   0.0        0     0.186508
# 23360  2018.0         4        4   0.0        0     0.090487
# 23361  2018.0         4        4   0.0        0     0.245074
# 23363  2018.0         4        4   0.0        0     0.337038
# 23365  2018.0         4        4   0.0        0     0.324866
# 23369  2018.0         4        4  57.0        1     0.135299
# 23381  2018.0         4        4   0.0        0     0.098526
# 23382  2018.0         4        4  52.0        1     0.083377
# 23387  2018.0         4        4   0.0        0     0.184172
# 23454  2018.0         5        4   0.0        0     0.680500
# 23470  2018.0         5        4   0.0        0     0.089102
# 23488  2018.0         5        4  58.0        1     0.084017
#
# [141 rows x 14 columns]

# %%
drafted = y_pred_proba_drafted.sort_values(by=['y_pred_prob'], ascending=False)

# %%
drafted
# Out:
#         #                   Player   Team_x   eFG%  ORB%  DRB%    FIC   PER  \
# 21662   1            Deandre Ayton   U of A  0.625  13.5  28.2  660.9  30.6
# 21380   1               Trae Young       OU  0.518   1.3   9.9  552.5  26.9
# 21730   1        Marvin Bagley III     DUKE  0.640  13.7  21.4  594.1  28.3
# 22483   3               Jon Elmore       MU  0.526   1.2  14.1  607.9  22.3
# 22581   1            Mikal Bridges     VILL  0.623   5.2  13.8  556.0  25.4
# 23454   1             Jock Landale      SMC  0.644  12.6  26.8  614.6  31.7
# 22781   1                Mike Daum     SDSU  0.543   6.7  28.2  566.5  29.6
# 21663   2       Wendell Carter Jr.     DUKE  0.591  12.8  23.1  529.8  26.4
# 22586   6             John Konchar     IPFW  0.569   6.2  20.0  564.4  22.5
# 22683   3             Ajdin Penava       MU  0.610   7.6  22.1  553.5  25.9
# 23067  14          Devonte' Graham       KU  0.510   2.0   9.6  558.5  20.2
# 22383   3            Jalen Brunson     VILL  0.604   1.2   9.7  513.2  24.7
# 23056   3             Jevon Carter      WVU  0.498   2.4  13.2  553.9  23.7
# 22598  18              Cody Martin      UNR  0.537   5.9  13.6  520.1  20.8
# 22692  12                Luke Maye      UNC  0.535  10.3  22.8  549.1  22.7
# 22127   4             Yoeli Childs      BYU  0.557   7.7  23.5  512.2  23.7
# 23382  29            Vince Edwards       PU  0.544   8.3  18.5  432.5  20.7
# 22603  23              Jacob Evans       UC  0.507   5.2  12.0  378.5  19.4
# 22490  10             Khyri Thomas       CU  0.629   4.0  11.0  391.4  20.6
#
#          year  position  colyear  Pick  drafted  y_pred_prob
# 21662  2018.0         4        1   1.0        1     0.927515
# 21380  2018.0         1        1   5.0        1     0.891374
# 21730  2018.0         5        1   2.0        1     0.889305
# 22581  2018.0         3        3  10.0        1     0.717176
# 21663  2018.0         4        1   7.0        1     0.601778
# 23067  2018.0         1        4  34.0        1     0.574660
# 22383  2018.0         1        3  33.0        1     0.534028
# 23056  2018.0         1        4  32.0        1     0.519076
# 21483  2018.0         2        1  11.0        1     0.458874
# 22027  2018.0         3        2  51.0        1     0.447155
# 22682  2018.0         4        3  48.0        1     0.436961
# 21731  2018.0         5        1   6.0        1     0.302432
# 21673  2018.0         4        1  30.0        1     0.221830
# 22025  2018.0         3        2  12.0        1     0.201670
# 21931  2018.0         2        2  17.0        1     0.168673
# 21480  2018.0         2        1  16.0        1     0.156721
# 21732  2018.0         5        1   4.0        1     0.156178
# 22391  2018.0         1        3  23.0        1     0.152159
# 21930  2018.0         2        2  26.0        1     0.137747
# 22600  2018.0         3        3  13.0        1     0.136541
# 22688  2018.0         4        3  56.0        1     0.136077
# 23369  2018.0         4        4  57.0        1     0.135299
# 22802  2018.0         5        3  49.0        1     0.126418
# 23176  2018.0         2        4  21.0        1     0.114502
# 21596  2018.0         3        1  37.0        1     0.107942
# 22791  2018.0         5        3  25.0        1     0.105412
# 22148  2018.0         4        2  19.0        1     0.095170
# 23488  2018.0         5        4  58.0        1     0.084017
# 22596  2018.0         3        3  35.0        1     0.083438
# 23382  2018.0         4        4  52.0        1     0.083377
# 22603  2018.0         3        3  28.0        1     0.081345
# 22490  2018.0         2        3  38.0        1     0.080292

# %% [markdown]
# ## Analyzing results and next steps
#
# #### Looking at the results of the model. It seems to understand weather the player will be selected better than the rank of each player. The rank of the player or how each team might select their future prospect doesn't only relay on the stats above. Player game IQ, combine results (tryout by each team), and interviews conducted for each players. All determine/effect player ranking.  The potential growth of each player once entering the NBA also effects the results.
# #### Unfortunately data on player game IQ, combine results (tryout by each team), and interviews conducted for each players are all not available to include in the model
# #### Next steps to have a better model would be:
# - look at each NBA team needs and fit the players accordingly
# - Predict the player performance in their first few years in the NBA

# %% [markdown]
# ## lets test this on 2019 Draft

# %%
#get the 2019 data
df_19 = df_final[df_final['year'].isin([2019])]
df_19.head()
# Out:
#        #              Player Team_x   eFG%  ORB%  DRB%    FIC   PER    year  \
# 23742  1       Jalen Pickett     SC  0.513   4.4  11.9  482.5  24.2  2019.0
# 23743  2  Darius Quisenberry    YSU  0.484   1.5  11.1  268.1  19.3  2019.0
# 23744  3          Coby White    UNC  0.516   1.3  11.4  341.2  18.6  2019.0
# 23745  4       Malachi Smith   WRST  0.455   8.0  14.8  166.9  17.9  2019.0
# 23746  5  Daivien Williamson   ETSU  0.575   1.6   8.7  213.6  17.9  2019.0
#
#        position  colyear  Pick  drafted
# 23742         1        1   0.0        0
# 23743         1        1   0.0        0
# 23744         1        1   0.0        0
# 23745         1        1   0.0        0
# 23746         1        1   0.0        0

# %%
Missing_draft_list = df_19[df_19['Player'].isin(['Cameron Johnson','Matisse Thybulle','Dylan Windler',
                            'Justin James','Eric Paschall','Admiral Schofield',
                            'Terance Mann','Quinndary Weatherspoon','Jarrell Brantley',
                            'Justin Wright-Foreman','Marial Shayok','Kezie Okpala'])]
Missing_draft_list
# Out:
#         #                  Player   Team_x   eFG%  ORB%  DRB%    FIC   PER  \
# 24451  17            Kezie Okpala       SU  0.507   4.1  14.9  262.6  17.4
# 25640   1   Justin Wright-Foreman      HOF  0.596   1.2  11.5  509.5  27.4
# 25649  10           Marial Shayok      ISU  0.573   5.1  11.7  362.4  21.3
# 25740   1           Dylan Windler      BEL  0.651   6.8  27.3  643.4  29.0
# 25745   6         Cameron Johnson      UNC  0.621   6.5  13.3  485.0  23.6
# 25748   9  Quinndary Weatherspoon      MSU  0.574   4.7  11.6  404.6  22.8
# 25754  15            Justin James       UW  0.454   3.2  22.2  439.8  20.9
# 25766  27       Admiral Schofield       UT  0.548   4.5  16.4  390.2  19.4
# 25770  31        Matisse Thybulle       UW  0.500   3.0   8.9  358.4  18.7
# 25841   2        Jarrell Brantley   C of C  0.559   6.6  24.2  482.9  26.9
# 25885  46            Terance Mann      FSU  0.557   9.1  14.2  384.8  17.9
# 26001  62           Eric Paschall     VILL  0.528   4.2  15.9  376.9  18.2
#
#          year  position  colyear  Pick  drafted
# 24451  2019.0         3        2   0.0        0
# 25640  2019.0         2        4   0.0        0
# 25649  2019.0         2        4   0.0        0
# 25740  2019.0         3        4   0.0        0
# 25745  2019.0         3        4   0.0        0
# 25748  2019.0         3        4   0.0        0
# 25754  2019.0         3        4   0.0        0
# 25766  2019.0         3        4   0.0        0
# 25770  2019.0         3        4   0.0        0
# 25841  2019.0         4        4   0.0        0
# 25885  2019.0         4        4   0.0        0
# 26001  2019.0         5        4   0.0        0

# %%
# players that declared to be part of the Draft
df_19_dec = pd.read_csv("2019 draft/2019 EC Draft.csv")
df_19_dec.shape
# Out:
# (99, 2)

# %%
# merge with players that declared to be part of the Draft
df_19_list = pd.merge(df_19, df_19_dec, how='left', on=['Player'])
df_19_list = df_19_list[df_19_list['Declared'].isin(['yes'])]
df_19_list
# Out:
#        #                    Player   Team_x   eFG%  ORB%  DRB%    FIC   PER  \
# 2      3                Coby White      UNC  0.516   1.3  11.4  341.2  18.6
# 100    1              R.J. Barrett     DUKE  0.506   4.8  17.2  536.2  22.5
# 102    3            Darius Garland       VU  0.639   1.6  11.7   49.8  20.1
# 104    5               Tyler Herro       UK  0.536   1.6  13.9  370.6  18.7
# 201    2             Nassir Little      UNC  0.504   9.2  16.9  232.2  19.1
# 202    3            Romeo Langford       IU  0.491   4.9  12.8  327.2  19.0
# 207    8            Keldon Johnson       UK  0.521   5.5  16.4  328.6  17.9
# 212   13                Louis King       UO  0.522   5.4  17.0  242.4  17.1
# 214   15       Talen Horton-Tucker      ISU  0.470   2.9  16.8  278.2  16.7
# 1464  67            Marques Bolden     DUKE  0.579  11.0  13.3  237.6  17.4
# 1835   1     Justin Wright-Foreman      HOF  0.596   1.2  11.5  509.5  27.4
# 1844  10             Marial Shayok      ISU  0.573   5.1  11.7  362.4  21.3
# 1935   1             Dylan Windler      BEL  0.651   6.8  27.3  643.4  29.0
# 1940   6           Cameron Johnson      UNC  0.621   6.5  13.3  485.0  23.6
# 1943   9    Quinndary Weatherspoon      MSU  0.574   4.7  11.6  404.6  22.8
# 1949  15              Justin James       UW  0.454   3.2  22.2  439.8  20.9
# 1961  27         Admiral Schofield       UT  0.548   4.5  16.4  390.2  19.4
# 1965  31          Matisse Thybulle       UW  0.500   3.0   8.9  358.4  18.7
# 2036   2          Jarrell Brantley   C of C  0.559   6.6  24.2  482.9  26.9
# 2080  46              Terance Mann      FSU  0.557   9.1  14.2  384.8  17.9
# 2196  62             Eric Paschall     VILL  0.528   4.2  15.9  376.9  18.2
#
#         year  position  colyear  Pick  drafted Declared
# 2     2019.0         1        1   0.0        0      yes
# 100   2019.0         2        1   0.0        0      yes
# 102   2019.0         2        1   0.0        0      yes
# 104   2019.0         2        1   0.0        0      yes
# 201   2019.0         3        1   0.0        0      yes
# 202   2019.0         3        1   0.0        0      yes
# 207   2019.0         3        1   0.0        0      yes
# 212   2019.0         3        1   0.0        0      yes
# 214   2019.0         3        1   0.0        0      yes
# 219   2019.0         3        1   0.0        0      yes
# 236   2019.0         3        1   0.0        0      yes
# 287   2019.0         4        1   0.0        0      yes
# 290   2019.0         4        1   0.0        0      yes
# 294   2019.0         4        1   0.0        0      yes
# 301   2019.0         4        1   0.0        0      yes
# 369   2019.0         5        1   0.0        0      yes
# 374   2019.0         5        1   0.0        0      yes
# 391   2019.0         5        1   0.0        0      yes
# 439   2019.0         1        2   0.0        0      yes
# 446   2019.0         1        2   0.0        0      yes
# 457   2019.0         1        2   0.0        0      yes
# 542   2019.0         2        2   0.0        0      yes
# 543   2019.0         2        2   0.0        0      yes
# 544   2019.0         2        2   0.0        0      yes
# 574   2019.0         2        2   0.0        0      yes
# 639   2019.0         3        2   0.0        0      yes
# 640   2019.0         3        2   0.0        0      yes
# 645   2019.0         3        2   0.0        0      yes
# 646   2019.0         3        2   0.0        0      yes
# 655   2019.0         3        2   0.0        0      yes
# ...      ...       ...      ...   ...      ...      ...
# 1117  2019.0         2        3   0.0        0      yes
# 1122  2019.0         2        3   0.0        0      yes
# 1128  2019.0         2        3   0.0        0      yes
# 1207  2019.0         3        3   0.0        0      yes
# 1217  2019.0         3        3   0.0        0      yes
# 1233  2019.0         3        3   0.0        0      yes
# 1263  2019.0         3        3   0.0        0      yes
# 1298  2019.0         4        3   0.0        0      yes
# 1299  2019.0         4        3   0.0        0      yes
# 1301  2019.0         4        3   0.0        0      yes
# 1335  2019.0         4        3   0.0        0      yes
# 1339  2019.0         4        3   0.0        0      yes
# 1362  2019.0         4        3   0.0        0      yes
# 1401  2019.0         5        3   0.0        0      yes
# 1409  2019.0         5        3   0.0        0      yes
# 1410  2019.0         5        3   0.0        0      yes
# 1413  2019.0         5        3   0.0        0      yes
# 1460  2019.0         5        3   0.0        0      yes
# 1464  2019.0         5        3   0.0        0      yes
# 1835  2019.0         2        4   0.0        0      yes
# 1844  2019.0         2        4   0.0        0      yes
# 1935  2019.0         3        4   0.0        0      yes
# 1940  2019.0         3        4   0.0        0      yes
# 1943  2019.0         3        4   0.0        0      yes
# 1949  2019.0         3        4   0.0        0      yes
# 1961  2019.0         3        4   0.0        0      yes
# 1965  2019.0         3        4   0.0        0      yes
# 2036  2019.0         4        4   0.0        0      yes
# 2080  2019.0         4        4   0.0        0      yes
# 2196  2019.0         5        4   0.0        0      yes
#
# [81 rows x 14 columns]

# %%
df_19_list.to_csv('df_19_list.csv', header=True, index=False)

# %%
#split the data to knowa
X_test_new = df_19_list.iloc[:,3:-3]
y_test_new = df_19_list.iloc[:, -3]

# %%
scaler = StandardScaler()
scaler.fit(X_test_new)
#X_test_new = scaler.transform(X_test_new)
X_test_new = pd.DataFrame(scaler.transform(X_test_new), columns=X_test_new.columns)
X_test_new
# Out:
#         eFG%      ORB%      DRB%       FIC       PER  year  position   colyear
# 0  -0.364047 -1.239239 -0.882409 -0.219182 -0.456285   0.0 -1.697405 -1.427523
# 1  -0.531211 -0.228525  0.331873  1.415521  0.391101   0.0 -0.898046 -1.427523
# 2   1.692076 -1.152607 -0.819601 -2.662013 -0.130367   0.0 -0.898046 -1.427523
# 3  -0.029718 -1.152607 -0.359012  0.027281 -0.434557   0.0 -0.898046 -1.427523
# 4  -0.564644  1.042088  0.269065 -1.132938 -0.347646   0.0 -0.098686 -1.427523
# 5  -0.781958 -0.199647 -0.589306 -0.336545 -0.369373   0.0 -0.098686 -1.427523
# 6  -0.280465 -0.026382  0.164385 -0.324808 -0.608380   0.0 -0.098686 -1.427523
# 7  -0.263748 -0.055260  0.290001 -1.047431 -0.782203   0.0 -0.098686 -1.427523
# 8  -1.133003 -0.777198  0.248129 -0.747316 -0.869114   0.0 -0.098686 -1.427523
# 9  -1.183153 -0.315158 -1.154575 -0.945157 -1.021209   0.0 -0.098686 -1.427523
# 10 -1.316884 -1.037096 -1.028960 -1.142998 -1.607861   0.0 -0.098686 -1.427523
# 11  2.845510  2.052802  0.541231  2.599213  3.715462   0.0  0.700673 -1.427523
# 12  3.179839  0.926577  0.164385 -0.512590  0.999481   0.0  0.700673 -1.427523
# 13 -0.113300 -0.257402  0.122514 -0.250199 -0.043456   0.0  0.700673 -1.427523
# 14 -1.032705  1.013210  0.813398 -0.728873 -0.760475   0.0  0.700673 -1.427523
# 15  1.157149  2.890251  1.148372 -0.323132  0.065184   0.0  1.500032 -1.427523
# 16 -0.514495  1.388618  0.750590 -0.694503 -0.456285   0.0  1.500032 -1.427523
# 17 -1.133003  0.377904  1.169308 -1.215092 -1.390582   0.0  1.500032 -1.427523
# 18  0.254461 -0.488423 -0.610242  2.627715  1.998962   0.0 -1.697405 -0.404254
# 73  1.391180  0.262394 -0.484627  0.986306  0.630108   0.0 -0.098686  1.642284
# 74  0.605507 -0.257402 -0.840537  0.312306  0.456285   0.0 -0.098686  1.642284
# 75 -1.400466 -0.690566  1.378667  0.607391  0.043456   0.0 -0.098686  1.642284
# 76  0.170879 -0.315158  0.164385  0.191590 -0.282462   0.0 -0.098686  1.642284
# 77 -0.631510 -0.748321 -1.405806 -0.074992 -0.434557   0.0 -0.098686  1.642284
# 78  0.354760  0.291271  1.797384  0.968702  1.347127   0.0  0.700673  1.642284
# 79  0.321327  1.013210 -0.296204  0.146321 -0.608380   0.0  0.700673  1.642284
# 80 -0.163450 -0.401790  0.059706  0.080095 -0.543196   0.0  1.500032  1.642284
#
# [81 rows x 8 columns]

# %%
#using our best model to predict 2019 data
y_pred_proba = (fitted_search.best_estimator_.predict_proba(X_test_new,)[:,1]).astype(bool)

# %%
y_pred_proba.sum()
# Out:
# 81

# %%
y_pred_proba_drafted = df_19_list[y_pred_proba ==1]
y_pred_proba_drafted.head()
# Out:
#      #          Player Team_x   eFG%  ORB%  DRB%    FIC   PER    year  \
# 2    3      Coby White    UNC  0.516   1.3  11.4  341.2  18.6  2019.0
# 100  1    R.J. Barrett   DUKE  0.506   4.8  17.2  536.2  22.5  2019.0
# 102  3  Darius Garland     VU  0.639   1.6  11.7   49.8  20.1  2019.0
# 104  5     Tyler Herro     UK  0.536   1.6  13.9  370.6  18.7  2019.0
# 201  2   Nassir Little    UNC  0.504   9.2  16.9  232.2  19.1  2019.0
#
#      position  colyear  Pick  drafted Declared
# 2           1        1   0.0        0      yes
# 100         2        1   0.0        0      yes
# 102         2        1   0.0        0      yes
# 104         2        1   0.0        0      yes
# 201         3        1   0.0        0      yes

# %%
y_pred_proba_drafted['y_pred_prob'] = fitted_search.best_estimator_.predict_proba(X_test_new,)[:,1][y_pred_proba ==1]

# %%
y_pred_proba_drafted
# Out:
#        #                    Player   Team_x   eFG%  ORB%  DRB%    FIC   PER  \
# 2      3                Coby White      UNC  0.516   1.3  11.4  341.2  18.6
# 100    1              R.J. Barrett     DUKE  0.506   4.8  17.2  536.2  22.5
# 102    3            Darius Garland       VU  0.639   1.6  11.7   49.8  20.1
# 104    5               Tyler Herro       UK  0.536   1.6  13.9  370.6  18.7
# 201    2             Nassir Little      UNC  0.504   9.2  16.9  232.2  19.1
# 202    3            Romeo Langford       IU  0.491   4.9  12.8  327.2  19.0
# 207    8            Keldon Johnson       UK  0.521   5.5  16.4  328.6  17.9
# 212   13                Louis King       UO  0.522   5.4  17.0  242.4  17.1
# 214   15       Talen Horton-Tucker      ISU  0.470   2.9  16.8  278.2  16.7
# 219   20             Luguentz Dort      ASU  0.467   4.5  10.1  254.6  16.0
# 236   37               Cam Reddish     DUKE  0.459   2.0  10.7  231.0  13.3
# 287    1           Zion Williamson     DUKE  0.708  12.7  18.2  677.4  37.8
# 290    4              Jaxson Hayes       UT  0.728   8.8  16.4  306.2  25.3
# 294    8          Ignas Brazdeikis       UM  0.531   4.7  16.2  337.5  20.5
# 1401  2019.0         5        3   0.0        0      yes     0.040141
# 1409  2019.0         5        3   0.0        0      yes     0.000678
# 1410  2019.0         5        3   0.0        0      yes     0.002052
# 1413  2019.0         5        3   0.0        0      yes     0.000023
# 1460  2019.0         5        3   0.0        0      yes     0.000490
# 1464  2019.0         5        3   0.0        0      yes     0.000300
# 1835  2019.0         2        4   0.0        0      yes     0.022518
# 1844  2019.0         2        4   0.0        0      yes     0.001066
# 1935  2019.0         3        4   0.0        0      yes     0.038047
# 1940  2019.0         3        4   0.0        0      yes     0.008739
# 1943  2019.0         3        4   0.0        0      yes     0.003471
# 1949  2019.0         3        4   0.0        0      yes     0.002764
# 1961  2019.0         3        4   0.0        0      yes     0.001499
# 1965  2019.0         3        4   0.0        0      yes     0.002131
# 2036  2019.0         4        4   0.0        0      yes     0.006147
# 2080  2019.0         4        4   0.0        0      yes     0.001431
# 2196  2019.0         5        4   0.0        0      yes     0.002612
#
# [81 rows x 15 columns]

# %%
draft_19_pred = y_pred_proba_drafted.sort_values(by=['y_pred_prob'], ascending=False)

# %%
draft_19_pred['Pick'] = draft_19_pred['y_pred_prob'].rank(ascending=False)
draft_19_pred['drafted'] = 1
draft_19_pred.head()
# Out:
#       #           Player Team_x   eFG%  ORB%  DRB%    FIC   PER    year  \
# 287   1  Zion Williamson   DUKE  0.708  12.7  18.2  677.4  37.8  2019.0
# 439   1        Ja Morant    MSU  0.553   3.9  12.7  680.8  29.9  2019.0
# 1298  1   Brandon Clarke     GU  0.693  13.9  19.7  683.4  34.6  2019.0
# 1299  2   Grant Williams     UT  0.582   8.5  17.3  592.2  28.8  2019.0
# 100   1     R.J. Barrett   DUKE  0.506   4.8  17.2  536.2  22.5  2019.0
#
#       position  colyear  Pick  drafted Declared  y_pred_prob
# 287          4        1   1.0        1      yes     0.529888
# 439          1        2   2.0        1      yes     0.383504
# 1298         4        3   3.0        1      yes     0.211482
# 1299         4        3   4.0        1      yes     0.094235
# 100          2        1   5.0        1      yes     0.059244

# %%
# as the college year effects the results of the player.. wanted to take a look at the rank
# for SOF and FR players
draft_19_pred_SOF_FR = draft_19_pred[draft_19_pred['colyear'].isin([1,2])]
draft_19_pred_SOF_FR['Pick'] = draft_19_pred_SOF_FR['y_pred_prob'].rank(ascending=False)
draft_19_pred_SOF_FR
# Out:
#       #                    Player   Team_x   eFG%  ORB%  DRB%    FIC   PER  \
# 287   1           Zion Williamson     DUKE  0.708  12.7  18.2  677.4  37.8
# 439   1                 Ja Morant      MSU  0.553   3.9  12.7  680.8  29.9
# 100   1              R.J. Barrett     DUKE  0.506   4.8  17.2  536.2  22.5
# 640   2            Jarrett Culver      TTU  0.505   5.7  17.2  489.0  24.1
# 846   8               Chuma Okeke       AU  0.577  10.6  16.9  477.0  23.0
# 843   5            Bruno Fernando      UMD  0.612  12.0  27.5  503.4  25.6
# 747   9           De'Andre Hunter      UVA  0.579   5.6  13.3  411.4  23.1
# 841   3            Daniel Gafford   U of A  0.660  11.2  22.7  452.1  26.7
# 841  2019.0         5        2   8.0        1      yes     0.010335
# 645  2019.0         3        2   9.0        1      yes     0.007857
# 742  2019.0         4        2  10.0        1      yes     0.007770
# 542  2019.0         2        2  11.0        1      yes     0.007108
# 857  2019.0         5        2  12.0        1      yes     0.006361
# 104  2019.0         2        1  13.0        1      yes     0.006158
# 294  2019.0         4        1  14.0        1      yes     0.005342
# 446  2019.0         1        2  15.0        1      yes     0.005330
# 202  2019.0         3        1  16.0        1      yes     0.004044
# 646  2019.0         3        2  17.0        1      yes     0.003832
# 2    2019.0         1        1  18.0        1      yes     0.003549
# 544  2019.0         2        2  19.0        1      yes     0.003345
# 457  2019.0         1        2  20.0        1      yes     0.002819
# 207  2019.0         3        1  21.0        1      yes     0.002494
# 756  2019.0         4        2  22.0        1      yes     0.002428
# 290  2019.0         4        1  23.0        1      yes     0.002260
# 639  2019.0         3        2  24.0        1      yes     0.001630
# 369  2019.0         5        1  25.0        1      yes     0.001470
# 219  2019.0         3        1  26.0        1      yes     0.001453
# 374  2019.0         5        1  27.0        1      yes     0.001387
# 214  2019.0         3        1  28.0        1      yes     0.001374
# 658  2019.0         3        2  29.0        1      yes     0.001323
# 787  2019.0         4        2  30.0        1      yes     0.001154
# 574  2019.0         2        2  31.0        1      yes     0.001127
# 774  2019.0         4        2  32.0        1      yes     0.001108
# 236  2019.0         3        1  33.0        1      yes     0.001004
# 301  2019.0         4        1  34.0        1      yes     0.000937
# 655  2019.0         3        2  35.0        1      yes     0.000660
# 212  2019.0         3        1  36.0        1      yes     0.000580
# 391  2019.0         5        1  37.0        1      yes     0.000472
# 201  2019.0         3        1  38.0        1      yes     0.000415
# 543  2019.0         2        2  39.0        1      yes     0.000222
# 679  2019.0         3        2  40.0        1      yes     0.000206
# 711  2019.0         3        2  41.0        1      yes     0.000156
# 102  2019.0         2        1  42.0        1      yes     0.000045

# %% [markdown]
# ##  Export Data to Visualize

# %%
#merge 2019 draft predictions to the rest of the data
#first drop columns (Declared & y_pred proba)
draft_19_pred_clean = draft_19_pred.drop(['Declared','y_pred_prob'], axis = 1)
draft_19_pred_clean.head()
# Out:
#       #           Player Team_x   eFG%  ORB%  DRB%    FIC   PER    year  \
# 287   1  Zion Williamson   DUKE  0.708  12.7  18.2  677.4  37.8  2019.0
# 439   1        Ja Morant    MSU  0.553   3.9  12.7  680.8  29.9  2019.0
# 1298  1   Brandon Clarke     GU  0.693  13.9  19.7  683.4  34.6  2019.0
# 1299  2   Grant Williams     UT  0.582   8.5  17.3  592.2  28.8  2019.0
# 100   1     R.J. Barrett   DUKE  0.506   4.8  17.2  536.2  22.5  2019.0
#
#       position  colyear  Pick  drafted
# 287          4        1   1.0        1
# 439          1        2   2.0        1
# 1298         4        3   3.0        1
# 1299         4        3   4.0        1
# 100          2        1   5.0        1

# %%
draft_19_pred_clean.to_csv('2019_Draft_Adv_pred.csv', header=True, index=False)

# %%
#get table with the history of drafted payers
df_final_hist = df_final[df_final['year'].isin([2009,2010,2011,2012,2013,2014,2015,2016,2017,2018])]
df_final_hist_drafted = df_final_hist[df_final_hist['drafted'].isin([1])]
df_final_hist_drafted.head()
# Out:
#       #         Player Team_x   eFG%  ORB%  DRB%    FIC   PER    year  \
# 101   2   Tyreke Evans     UM  0.489   4.9  15.1  412.2  24.1  2009.0
# 112  13   Jrue Holiday   UCLA  0.504   5.8  11.9  288.9  17.3  2009.0
# 211  12  DeMar DeRozan    USC  0.531   9.1  11.7  312.2  18.5  2009.0
# 337   2  Byron Mullens    OSU  0.638  11.5  17.2  222.4  21.8  2009.0
# 412   1    Jeff Teague     WF  0.546   1.7   8.6  353.9  23.0  2009.0
#
#      position  colyear  Pick  drafted
# 101         2        1   4.0        1
# 112         2        1  17.0        1
# 211         3        1   9.0        1
# 337         5        1  24.0        1
# 412         1        2  19.0        1

# %%
#now merge hist draft results with 2019 pred draft results tables
Draft_results = pd.concat([df_final_hist_drafted,draft_19_pred_clean])
Draft_results.shape
# Out:
# (513, 13)

# %%
#All data
Draft_results_all = pd.concat([df_final_hist,draft_19_pred_clean])
Draft_results.shape
# Out:
# (23055, 13)

# %%
Draft_results_all.to_csv('Draft_results_All_Adv_pred.csv', header=True, index=False)

# %%
print(df_final_hist_drafted.shape)
print(draft_19_pred_clean.shape)a
# Out:
# (451, 13)
# (62, 13)

# %%
Draft_results.to_csv('Draft_results_Adv_pred.csv', header=True, index=False)

# %% [markdown]
# ### Check the most similar players to the top 5 2019 draft picks

# %%
# first we have to scale the data
Stats_scaled = Draft_results[['eFG%','ORB%','DRB%','FIC','PER']].copy()

# %%
Stats_scaled.head()
# Out:
#       eFG%  ORB%  DRB%    FIC   PER
# 101  0.489   4.9  15.1  412.2  24.1
# 112  0.504   5.8  11.9  288.9  17.3
# 211  0.531   9.1  11.7  312.2  18.5
# 337  0.638  11.5  17.2  222.4  21.8
# 412  0.546   1.7   8.6  353.9  23.0

# %%
scaler = StandardScaler()
scaler.fit(Stats_scaled)
#Stats_scaled[Stats_scaled.columns] = scaler.fit_transform(Stats_scaled[Stats_scaled.columns])
Stats_scaled = pd.DataFrame(scaler.transform(Stats_scaled), columns=Stats_scaled.columns,index =Stats_scaled.index )
Stats_scaled.head()
# Out:
#          eFG%      ORB%      DRB%       FIC       PER
# 101 -1.083862 -0.464532 -0.214338 -0.032517  0.357305
# 112 -0.782843 -0.246659 -0.773195 -1.255035 -1.262689
# 211 -0.241010  0.552210 -0.808124 -1.024016 -0.976808
# 337  1.906254  1.133205  0.152413 -1.914382 -0.190634
# 412  0.060008 -1.239192 -1.349517 -0.610561  0.095247

# %%
#add the player name and position to the scaled data
Stats_scaled['Player'] = Draft_results['Player']
Stats_scaled['position'] = Draft_results['position']

# %%
Stats_scaled.head()
# Out:
#          eFG%      ORB%      DRB%       FIC       PER         Player  position
# 101 -1.083862 -0.464532 -0.214338 -0.032517  0.357305   Tyreke Evans         2
# 112 -0.782843 -0.246659 -0.773195 -1.255035 -1.262689   Jrue Holiday         2
# 211 -0.241010  0.552210 -0.808124 -1.024016 -0.976808  DeMar DeRozan         3
# 337  1.906254  1.133205  0.152413 -1.914382 -0.190634  Byron Mullens         5
# 412  0.060008 -1.239192 -1.349517 -0.610561  0.095247    Jeff Teague         1

# %%
#assing the player name as the index column
Stats_scaled.index = Stats_scaled['Player'] 
Stats_scaled.head()
# Out:
#                    eFG%      ORB%      DRB%       FIC       PER  \
# Player
# Tyreke Evans  -1.083862 -0.464532 -0.214338 -0.032517  0.357305
# Jrue Holiday  -0.782843 -0.246659 -0.773195 -1.255035 -1.262689
# DeMar DeRozan -0.241010  0.552210 -0.808124 -1.024016 -0.976808
# Byron Mullens  1.906254  1.133205  0.152413 -1.914382 -0.190634
# Jeff Teague    0.060008 -1.239192 -1.349517 -0.610561  0.095247
#
#                       Player  position
# Player
# Tyreke Evans    Tyreke Evans         2
# Jrue Holiday    Jrue Holiday         2
# DeMar DeRozan  DeMar DeRozan         3
# Byron Mullens  Byron Mullens         5
# Jeff Teague      Jeff Teague         1

# %%
# drop the player column
Stats_scaled = Stats_scaled.drop(['Player'],axis=1)
#df.drop(['B', 'C'], axis=1)

# %%
Stats_scaled.shape
# Out:
# (513, 6)

# %%
#check the top 5 players results
Top_5 = []
player = ('Zion Williamson','Ja Morant','Brandon Clarke','Grant Williams','R.J. Barrett')
for i in player:
    X = np.array(Stats_scaled.loc[i,:])
    Top_5.append(X)  
Top_5
# Out:
# [array([3.31100663, 1.42370217, 0.32705558, 2.59693979, 3.62111664,
#         4.        ]),
#  array([ 0.20048333, -0.70661307, -0.63348082,  2.63065077,  1.73906478,
#          1.        ]),
#  array([3.00998825, 1.7141997 , 0.58902005, 2.65642975, 2.85876652,
#         4.        ]),
#  array([0.78245221, 0.40696081, 0.1698769 , 1.75218233, 1.47700692,
#         4.        ]),
#  array([-0.74270761, -0.48873992,  0.1524126 ,  1.19694268, -0.02386988,
#          2.        ])]

# %%
# assign each array with the player name
Zion_Williamson = np.array(Stats_scaled.loc['Zion Williamson',:])
Ja_Morant = np.array(Stats_scaled.loc['Ja Morant',:])
Brandon_Clarke = np.array(Stats_scaled.loc['Brandon Clarke',:])
Grant_Williams = np.array(Stats_scaled.loc['Grant Williams',:])
RJ_Barrett = np.array(Stats_scaled.loc['R.J. Barrett',:])

# %%
# list of all drafted players scales
list_of_players = Stats_scaled.values
list_of_players.shape
# Out:
# (513, 6)

# %% [markdown]
# ### Check the most similar players using the euclidean distance

# %%
Zion_difference = []
for i,j in enumerate(list_of_players):
    Diff = np.linalg.norm(Zion_Williamson-j)
    player_name = Stats_scaled.index[i]
    Zion_difference.append([Diff,player_name])
#difference = pd.DataFrame(difference)

Zion = pd.DataFrame(Zion_difference)

Zion_sorted = Zion.sort_values(by=0,ascending=[True])
Zion_sorted.head(10)
# Out:
#             0                  1
# 451  0.000000    Zion Williamson
# 453  0.910134     Brandon Clarke
# 147  2.658243      Anthony Davis
# 105  2.783459   Derrick Williams
# 338  2.917021       Jakob Poeltl
# 283  2.959264      Jahlil Okafor
# 415  2.971673      Deandre Ayton
# 213  2.989859       Kelly Olynyk
# 11   2.995286      Blake Griffin
# 419  3.006234  Marvin Bagley III

# %%
Ja_diff = []
for i,j in enumerate(list_of_players):
    Diff = np.linalg.norm(Ja_Morant-j)
    player_name = Stats_scaled.index[i]
    Ja_diff.append([Diff,player_name])
#difference = pd.DataFrame(difference)

Ja = pd.DataFrame(Ja_diff)

Ja_sorted = Ja.sort_values(by=0,ascending=[True])
Ja_sorted.head(10)
# Out:
#             0                1
# 452  0.000000        Ja Morant
# 215  1.112816     Nate Wolters
# 341  1.454589       Kay Felder
# 12   1.535813    Stephen Curry
# 195  1.643443       Trey Burke
# 121  1.680372  Jimmer Fredette
# 107  1.702485     Kemba Walker
# 406  1.804892       Trae Young
# 285  1.807499    Cameron Payne
# 162  1.858049   Damian Lillard

# %%
Brandon_diff = []
for i,j in enumerate(list_of_players):
    Diff = np.linalg.norm(Brandon_Clarke-j)
    player_name = Stats_scaled.index[i]
    Brandon_diff.append([Diff,player_name])
#difference = pd.DataFrame(difference)

Brandon = pd.DataFrame(Brandon_diff)

Brandon_sorted = Brandon.sort_values(by=0,ascending=[True])
Brandon_sorted.head(10)
# Out:
#             0                  1
# 453  0.000000     Brandon Clarke
# 451  0.910134    Zion Williamson
# 147  2.209590      Anthony Davis
# 415  2.243446      Deandre Ayton
# 105  2.247683   Derrick Williams
# 419  2.293101  Marvin Bagley III
# 338  2.304811       Jakob Poeltl
# 283  2.357063      Jahlil Okafor
# 355  2.422106      Brice Johnson
# 381  2.489374       John Collins

# %%
Grant_diff = []
for i,j in enumerate(list_of_players):
    Diff = np.linalg.norm(Grant_Williams-j)
    player_name = Stats_scaled.index[i]
    Grant_diff.append([Diff,player_name])
#difference = pd.DataFrame(difference)

Grant = pd.DataFrame(Grant_diff)

Grant_sorted = Grant.sort_values(by=0,ascending=[True])
Grant_sorted.head(10)
# Out:
#             0                 1
# 454  0.000000    Grant Williams
# 38   0.817441   DeMarre Carroll
# 178  0.834569       Jae Crowder
# 267  1.199911  Cameron Bairstow
# 59   1.264882      Luke Babbitt
# 116  1.269790     Marcus Morris
# 271  1.358591    Doug McDermott
# 85   1.405680  Quincy Pondexter
# 309  1.424168       Aaron White
# 229  1.498729       Jeff Withey

# %%
RJ_Barrett_Diff = []
for i,j in enumerate(list_of_players):
    Diff = np.linalg.norm(RJ_Barrett-j)
    player_name = Stats_scaled.index[i]
    RJ_Barrett_Diff.append([Diff,player_name])
#difference = pd.DataFrame(difference)

RJ = pd.DataFrame(RJ_Barrett_Diff)

RJ_Barrett_sorted = RJ.sort_values(by=0,ascending=[True])
RJ_Barrett_sorted.head(10)
# Out:
#             0                    1
# 455  0.000000         R.J. Barrett
# 260  0.740182       Shabazz Napier
# 387  0.948127  Nigel Williams-Goss
# 79   1.025274       Da'Sean Butler
# 344  1.063645      DeAndre' Bembry
# 275  1.142229     D'Angelo Russell
# 459  1.188351       Jarrett Culver
# 203  1.221960         Ray McCallum
# 241  1.230876         Marcus Smart
# 66   1.261101      Dominique Jones
